# %%
import pandas as pd
import tensorflow as tf
import tensorflow.keras as keras

# %% [markdown]
# # **Load from Keras**

# %%
url =  'https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
keras.utils.get_file('auto-mpg.data', url)
# Out:
# ...
# 40960/30286 [========================================] - 0s 0us/step
# '/root/.keras/datasets/auto-mpg.data'

# %%
# !head /root/.keras/datasets/auto-mpg.data
# Out:
# 18.0   8   307.0      130.0      3504.      12.0   70  1	"chevrolet chevelle malibu"
# 15.0   8   350.0      165.0      3693.      11.5   70  1	"buick skylark 320"
# 18.0   8   318.0      150.0      3436.      11.0   70  1	"plymouth satellite"
# 16.0   8   304.0      150.0      3433.      12.0   70  1	"amc rebel sst"
# 17.0   8   302.0      140.0      3449.      10.5   70  1	"ford torino"
# 15.0   8   429.0      198.0      4341.      10.0   70  1	"ford galaxie 500"
# 14.0   8   454.0      220.0      4354.       9.0   70  1	"chevrolet impala"
# 14.0   8   440.0      215.0      4312.       8.5   70  1	"plymouth fury iii"
# 14.0   8   455.0      225.0      4425.      10.0   70  1	"pontiac catalina"
# 15.0   8   390.0      190.0      3850.       8.5   70  1	"amc ambassador dpl"

# %%
df = pd.read_csv('/root/.keras/datasets/auto-mpg.data', header=None, delim_whitespace=True)
df.head()
# Out:
#       0  1      2      3       4     5   6  7                          8
# 0  18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1  15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2  18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3  16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4  17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino

# %% [markdown]
# # **Import files from device**

# %%
from google.colab import files
uploaded = files.upload()
# can upload csv files and py scripts to get access to functions
# Out:
#      <input type="file" id="files-243d04fa-c2c5-4bd7-9919-4293b9e4942e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-243d04fa-c2c5-4bd7-9919-4293b9e4942e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pwd # current path
# Out:
# /content

# %% [markdown]
# # **Import from google drive**

# %%
from google.colab import drive
drive.mount('/content/driveb')
# Out:
# Mounted at /content/drive

# %%
# !ls drive
# Out:
# MyDrive

# %%
# !ls '/content/drive/MyDrive'
# Out:
# 'Pytorch Course'
